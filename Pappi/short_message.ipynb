# %% [markdown]
# # -*- coding: utf-8 -*-
# """Day1.ipynb
#
# Automatically generated by Colab.
#
# Original file is located
# [here](https://colab.research.google.com/drive/18VpatuQnZ-JfgT7rilr3k5aMY6DZytL_)
# """

# %%
print("Hello, Python World!")

print("The number is", 4)
print("2 + 2 =", 3 + 2)
# Out:
# Hello, Python World!
# The number is 4
# 2 + 2 = 5

# %%
name = "Vivian"
print(f"Hello, {name}! Welcome to Python Programming")

userName = input("What is your name? ")
print(f"Hello, {userName}! Welcome to Python Programming")
# Out:
# Hello, Vivian! Welcome to Python Programming
# What is your name? paul
# Hello, paul! Welcome to Python Programming

# %%
from datetime import datetime as dt
# Welcome Message Generator

# Step 1: Ask for user details
name = input("What's your name? ")
name = name.capitalize()
hobby = input("What's your favorite hobby? ")
color = input("what's your favourite color?")

today = dt.now()
today = today.strftime("%A, %d , %B, %Y")

# Step 2: Generate a personalized welcome message
print("\n--- Welcome Message ---")
print(f"Hello, {name}! 👋")
print(f"Welcome to the world of Python Programming.")
print(f"It's great to know that you love {hobby}.")
print(f"I also like the color {color}")
print(f"Get ready to build something amazing today.")
print(f"the date today is {today}")
# Out:
# What's your name? paul
# What's your favorite hobby? eating
